# %% [markdown]
# # mapping world population data: JSON file

# %%
import json
filepath = "C:/Users/mirya/Downloads/worldpopulation.json"

# %%
with open(filepath) as f:
    pop_data = json.load(f)
pop_data
# Out:
# [{'Rank': '1',
#   'country': 'China',
#   'population': '1388232693',
#   'World': '0.185'},
#  {'Rank': '2',
#   'country': 'India',
#   'population': '1342512706',
#   'World': '0.179'},
#  {'Rank': '3', 'country': 'U.S.', 'population': '326474013', 'World': '0.043'},
#  {'Rank': '4',
#   'country': 'Indonesia',
#   'population': '263510146',
#   'World': '0.035'},
#  {'Rank': '5',
#   'country': 'Brazil',
#   'population': '211243220',
#   'World': '0.028'},
#  {'Rank': '6',
#   'country': 'Pakistan',
#   'population': '196744376',
#   'World': '0.026'},
#  {'Rank': '7',
#   'country': 'Nigeria',
#   'population': '191835936',
#   'World': '0.026'},
#  {'Rank': '8',
#   'country': 'Bangladesh',
#   'population': '164827718',
#   'World': '0.022'},
#  {'Rank': '9',
#   'country': 'Russia',
#   'population': '143375006',
#   'World': '0.019'},
#  {'Rank': '10',
#   'country': 'Mexico',
#   'population': '130222815',
#   'World': '0.017'},
#  {'Rank': '11',
#   'country': 'Japan',
# ...

# %%
# printing all countries population
for pop in pop_data:
    print(pop['country'],":",pop['population'])
# Out:
# China : 1388232693
# India : 1342512706
# U.S. : 326474013
# Indonesia : 263510146
# Brazil : 211243220
# Pakistan : 196744376
# Nigeria : 191835936
# Bangladesh : 164827718
# Russia : 143375006
# Mexico : 130222815
# Japan : 126045211
# Ethiopia : 104344901
# Philippines : 103796832
# Viet Nam : 95414640
# Egypt : 95215102
# DR Congo : 82242685
# Iran : 80945718
# Germany : 80636124
# Turkey : 80417526
# Thailand : 68297547
# U.K. : 65511098
# France : 64938716
# Italy : 59797978
# Tanzania : 56877529
# South Africa : 55436360
# Myanmar : 54836483
# South Korea : 50704971
# Colombia : 49067981
# Kenya : 48466928
# Spain : 46070146
# Ukraine : 44405055
# Argentina : 44272125
# Sudan : 42166323
# Uganda : 41652938
# Algeria : 41063753
# Iraq : 38654287
# Poland : 38563573
# Canada : 36626083
# Morocco : 35241418
# Afghanistan : 34169169
# Saudi Arabia : 32742664
# Peru : 32166473
# Venezuela : 31925705
# Malaysia : 31164177
# Uzbekistan : 30690914
# Mozambique : 29537914
# ...

# %%
# converting the population value to integer

for pop in pop_data:
    population = pop['population']
    country = pop['country']
    print(country + ":" + population)
# Out:
# China:1388232693
# India:1342512706
# U.S.:326474013
# Indonesia:263510146
# Brazil:211243220
# Pakistan:196744376
# Nigeria:191835936
# Bangladesh:164827718
# Russia:143375006
# Mexico:130222815
# Japan:126045211
# Ethiopia:104344901
# Philippines:103796832
# Viet Nam:95414640
# Egypt:95215102
# DR Congo:82242685
# Iran:80945718
# Germany:80636124
# Turkey:80417526
# Thailand:68297547
# U.K.:65511098
# France:64938716
# Italy:59797978
# Tanzania:56877529
# South Africa:55436360
# Myanmar:54836483
# South Korea:50704971
# Colombia:49067981
# Kenya:48466928
# Spain:46070146
# Ukraine:44405055
# Argentina:44272125
# Sudan:42166323
# Uganda:41652938
# Algeria:41063753
# Iraq:38654287
# Poland:38563573
# Canada:36626083
# Morocco:35241418
# Afghanistan:34169169
# Saudi Arabia:32742664
# Peru:32166473
# Venezuela:31925705
# Malaysia:31164177
# Uzbekistan:30690914
# Mozambique:29537914
# Nepal:29187037
# Ghana:28656723
# Yemen:28119546
# Angola:26655513
# Madagascar:25612972
# ...

# %% [markdown]
# Obtaining two digit country codes for mapping using pygal

# %%
from pygal_maps_world.i18n import COUNTRIES
for country_code in sorted(COUNTRIES.keys()):
    print(country_code, COUNTRIES[country_code])
# Out:
# ad Andorra
# ae United Arab Emirates
# af Afghanistan
# al Albania
# am Armenia
# ao Angola
# aq Antarctica
# ar Argentina
# at Austria
# au Australia
# az Azerbaijan
# ba Bosnia and Herzegovina
# bd Bangladesh
# be Belgium
# bf Burkina Faso
# bg Bulgaria
# bh Bahrain
# bi Burundi
# bj Benin
# bn Brunei Darussalam
# bo Bolivia, Plurinational State of
# br Brazil
# bt Bhutan
# bw Botswana
# by Belarus
# bz Belize
# ca Canada
# cd Congo, the Democratic Republic of the
# cf Central African Republic
# cg Congo
# ch Switzerland
# ci Cote d'Ivoire
# cl Chile
# cm Cameroon
# cn China
# co Colombia
# cr Costa Rica
# cu Cuba
# cv Cape Verde
# cy Cyprus
# cz Czech Republic
# de Germany
# dj Djibouti
# dk Denmark
# do Dominican Republic
# dz Algeria
# ec Ecuador
# ee Estonia
# eg Egypt
# eh Western Sahara
# er Eritrea
# es Spain
# et Ethiopia
# fi Finland
# fr France
# ga Gabon
# gb United Kingdom
# ge Georgia
# gf French Guiana
# gh Ghana
# gl Greenland
# gm Gambia
# gn Guinea
# ...

# %%
# function for extracting country codes

def get_country_code(country_name):
    for code, name in COUNTRIES.items():
        if name==country_name:
            return code
    return None
get_country_code('India')
# Out:
# 'in'

# %%
# connecting countries codes with json file

for pop in pop_data:
    country_name = pop['country']
    population = int(float(pop['population']))
    code = get_country_code(country_name)
    if code:
        print(code + ":" + str(population))
    else:
        print("ERROR" + ":" + country_name)
# Out:
# cn:1388232693
# in:1342512706
# ERROR:U.S.
# id:263510146
# br:211243220
# pk:196744376
# ng:191835936
# bd:164827718
# ERROR:Russia
# mx:130222815
# jp:126045211
# et:104344901
# ph:103796832
# vn:95414640
# eg:95215102
# ERROR:DR Congo
# ERROR:Iran
# de:80636124
# tr:80417526
# th:68297547
# ERROR:U.K.
# fr:64938716
# it:59797978
# ERROR:Tanzania
# za:55436360
# mm:54836483
# ERROR:South Korea
# co:49067981
# ke:48466928
# es:46070146
# ua:44405055
# ar:44272125
# sd:42166323
# ug:41652938
# dz:41063753
# iq:38654287
# pl:38563573
# ca:36626083
# ma:35241418
# af:34169169
# sa:32742664
# pe:32166473
# ERROR:Venezuela
# my:31164177
# uz:30690914
# mz:29537914
# np:29187037
# gh:28656723
# ye:28119546
# ao:26655513
# mg:25612972
# ERROR:North Korea
# au:24641662
# cm:24513689
# ERROR:C̫te d'Ivoire
# ne:21563607
# lk:20905335
# ro:19237513
# bf:19173322
# ERROR:Syria
# ml:18689966
# cl:18313495
# mw:18298679
# kz:18064470
# zm:17237931
# nl:17032845
# gt:17005497
# ec:16625776
# ...

# %%
# plotting world map
from pygal_maps_world.maps import World

wm = World()
wm.add('Asia',['in','cn','jp'])

wm.render_to_file('map.svg')

# %%
wm = World()
wm.add('Asia',{'in':1342512706,'cn':138})
wm.render_to_file('map.svg')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("C:/Users/mirya/OneDrive/Pictures/Screenshots/Screenshot (197).png")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Plotting complete Population Map

# %%
import json
import pygal
with open(filepath) as f:
    pop_data = json.load(f)

cc_populations = {}
for pop in pop_data:
    country = pop['country']
    population = int(float(pop['population']))
    code = get_country_code(country)
    if code:
        cc_populations[code] = population

wm = World()
wm.title = "World Population in 2017 by Country"
wm.add('2017', cc_populations)
wm.render_to_file('worldpopulation.svg')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("C:/Users/mirya/OneDrive/Pictures/Screenshots/Screenshot (196).png")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Grouping countries into 3 population levels

# %%
cc_pop1, cc_pop2, cc_pop3 = {}, {}, {}
for cc, pop in cc_populations.items():
    if pop<10000000:
        cc_pop1[cc] = pop
    elif pop<1000000000:
        cc_pop2[cc] = pop
    else:
        cc_pop3[cc] = pop

# how many countries are in each levl
print(len(cc_pop1), len(cc_pop2), len(cc_pop3))
# Out:
# 78 72 2

# %%
wm = World()
wm.title='World Population in 2017, by Country'
wm.add('0-10m', cc_pop1)
wm.add('10m-1bn', cc_pop2)
wm.add('>1bn',cc_pop3)
wm.render_to_file('worldpopulation.svg')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("C:/Users/mirya/OneDrive/Pictures/Screenshots/Screenshot (198).png")
imgplot = plt.imshow(img)
plt.show()
